# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_excel("employee-salary.xlsx")
print(df)
print(df.head())
print("\n")
print(df.tail())
print("\n")
df.info()
print("\n")
print(df.describe())
print("\n")
print(df.shape)
print("\n")
print(df.isnull().sum())
print("\n")
print(df.duplicated().sum())
print("\n")
print(df["Department"].unique())
print("\n")
print(df["Department"].value_counts())
# Out:
#            Name  Department  Experience_Years Education_Level  Age  Gender  \
# 0    Employee_1   Marketing                15          Master   53       2
# 1    Employee_2  Operations                 7        Bachelor   25       2
# 2    Employee_3          IT                12     High School   51       2
# 3    Employee_4  Operations                 8             PhD   44       1
# 4    Employee_5  Operations                15          Master   36       2
# 5    Employee_6     Finance                 3     High School   50       1
# 6    Employee_7          IT                14             PhD   57       1
# 7    Employee_8          IT                17             PhD   34       2
# 8    Employee_9          IT                 4        Bachelor   53       1
# 9   Employee_10  Operations                18     High School   28       1
# 10  Employee_11   Marketing                 8             PhD   43       1
# 11  Employee_12          IT                 4          Master   49       2
# 12  Employee_13  Operations                 2          Master   23       2
# 13  Employee_14     Finance                 6        Bachelor   27       1
# 14  Employee_15   Marketing                10             PhD   49       2
# 15  Employee_16     Finance                 4     High School   49       2
# 16  Employee_17   Marketing                18          Master   41       2
# 17  Employee_18  Operations                12             PhD   51       2
# 18  Employee_19          HR                 2             PhD   32       1
# 19  Employee_20   Marketing                10        Bachelor   49       1
# 20  Employee_21     Finance                 4          Master   46       2
# 21  Employee_22  Operations                14          Master   54       2
# 22  Employee_23   Marketing                16     High School   22       1
# 23  Employee_24          HR                15          Master   48       1
# 24  Employee_25          HR                 8     High School   34       2
# 25  Employee_26          IT                14          Master   24       1
# 26  Employee_27          IT                 8        Bachelor   27       2
# 27  Employee_28     Finance                16          Master   29       2
# 28  Employee_29   Marketing                13     High School   48       1
# 29  Employee_30   Marketing                18     High School   30       1
# 30  Employee_31          IT                15        Bachelor   54       2
# 31  Employee_32   Marketing                13          Master   45       2
# 32  Employee_33   Marketing                 9          Master   36       1
# 33  Employee_34          HR                15        Bachelor   53       2
# 34  Employee_35          IT                13          Master   53       1
# 35  Employee_36  Operations                 1          Master   45       2
# 36  Employee_37          IT                 7     High School   33       1
# 37  Employee_38  Operations                 9          Master   23       1
# 38  Employee_39          HR                 1          Master   24       1
# 39  Employee_40     Finance                12        Bachelor   38       2
# 40  Employee_41   Marketing                 8        Bachelor   23       2
# 41  Employee_42          HR                11             PhD   23       1
# 42  Employee_43   Marketing                19     High School   49       2
# 43  Employee_44     Finance                17          Master   44       1
# 44  Employee_45     Finance                 8          Master   53       1
# 45  Employee_46          HR                 3             PhD   54       2
# 46  Employee_47     Finance                 3          Master   22       2
# 47  Employee_48  Operations                 1     High School   40       1
# 48  Employee_49     Finance                 5             PhD   23       2
# 49  Employee_50   Marketing                10     High School   47       2
#
#          City  Monthly_Salary
# 0       Delhi          111416
# 1   Bangalore           95271
# 2   Hyderabad           69064
# 3       Delhi           95091
# 4       Delhi          132450
# 5      Mumbai           65818
# 6      Mumbai           70525
# 7   Bangalore           44830
# 8   Hyderabad           42429
# 9      Mumbai           31893
# 10      Delhi          141381
# 11  Hyderabad          104909
# 12  Hyderabad           72333
# 13      Delhi           28436
# 14     Mumbai           99290
# 15      Delhi          101213
# 16  Hyderabad           30895
# 17    Chennai           44738
# 18    Chennai           55746
# 19  Bangalore           74377
# 20      Delhi           73404
# 21      Delhi           79045
# 22  Bangalore          122888
# 23  Bangalore           64790
# 24  Bangalore          132455
# 25  Hyderabad           30600
# 26      Delhi          119660
# 27  Hyderabad          118179
# 28  Bangalore           65764
# 29      Delhi           99543
# 30  Hyderabad           70714
# 31  Hyderabad           81835
# 32  Bangalore          127946
# 33      Delhi          134616
# 34  Bangalore          130983
# 35      Delhi           98744
# 36    Chennai           81491
# 37     Mumbai          149123
# 38     Mumbai           43589
# 39     Mumbai           68484
# 40  Bangalore          107989
# 41    Chennai           61212
# 42      Delhi           68525
# 43  Hyderabad           72202
# 44      Delhi           57635
# 45  Hyderabad           88208
# 46      Delhi           58828
# 47    Chennai           43711
# 48  Hyderabad           28420
# 49  Bangalore          121752
#          Name  Department  Experience_Years Education_Level  Age  Gender  \
# 0  Employee_1   Marketing                15          Master   53       2
# 1  Employee_2  Operations                 7        Bachelor   25       2
# 2  Employee_3          IT                12     High School   51       2
# 3  Employee_4  Operations                 8             PhD   44       1
# 4  Employee_5  Operations                15          Master   36       2
#
#         City  Monthly_Salary
# 0      Delhi          111416
# 1  Bangalore           95271
# 2  Hyderabad           69064
# 3      Delhi           95091
# 4      Delhi          132450
#
#
#            Name  Department  Experience_Years Education_Level  Age  Gender  \
# 45  Employee_46          HR                 3             PhD   54       2
# 46  Employee_47     Finance                 3          Master   22       2
# 47  Employee_48  Operations                 1     High School   40       1
# 48  Employee_49     Finance                 5             PhD   23       2
# 49  Employee_50   Marketing                10     High School   47       2
#
#          City  Monthly_Salary
# 45  Hyderabad           88208
# 46      Delhi           58828
# 47    Chennai           43711
# 48  Hyderabad           28420
# 49  Bangalore          121752
#
#
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              50 non-null     str
#  1   Department        50 non-null     str
#  2   Experience_Years  50 non-null     int64
#  3   Education_Level   50 non-null     str
#  4   Age               50 non-null     int64
#  5   Gender            50 non-null     int64
#  6   City              50 non-null     str
#  7   Monthly_Salary    50 non-null     int64
# dtypes: int64(4), str(4)
# memory usage: 3.3 KB
#
#
#        Experience_Years        Age     Gender  Monthly_Salary
# count         50.000000  50.000000  50.000000         50.0000
# mean           9.900000  39.760000   1.540000      82288.8000
# std            5.349995  11.539745   0.503457      33521.4379
# min            1.000000  22.000000   1.000000      28420.0000
# 25%            5.250000  28.250000   1.000000      59424.0000
# 50%           10.000000  43.500000   2.000000      73890.5000
# 75%           14.750000  49.000000   2.000000     107219.0000
# max           19.000000  57.000000   2.000000     149123.0000
#
#
# (50, 8)
#
#
# Name                0
# Department          0
# Experience_Years    0
# Education_Level     0
# Age                 0
# Gender              0
# City                0
# Monthly_Salary      0
# dtype: int64
#
#
# 0
#
#
# <StringArray>
# ['Marketing', 'Operations', 'IT', 'Finance', 'HR']
# Length: 5, dtype: str
#
#
# Department
# Marketing     13
# Operations    10
# IT            10
# Finance       10
# HR             7
# Name: count, dtype: int64
