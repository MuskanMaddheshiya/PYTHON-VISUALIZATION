# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("sales_dataset.csv")
print(df)
df["Revenue"]= df["Sales"]
product_sales = df.groupby("Product Name")["Sales"].sum()
print("Product-wise Sales")
print(product_sales)
category_revenue = df.groupby("Category")["Revenue"].sum()
print("Category-wise Revenue")
print(category_revenue)
city_revenue = df.groupby("City")["Revenue"].sum()
print("City-wise Revenue")
print(city_revenue)
# Out:
#     Order Date         Category Product Name     City  Sales  Profit  \
# 0     1/5/2024  Office Supplies        Paper   Mumbai   1200     200
# 1    1/12/2024       Technology       Laptop    Delhi  55000    8000
# 2     2/3/2024        Furniture        Chair  Lucknow   4500     700
# 3    2/15/2024  Office Supplies          Pen   Kanpur    600     120
# 4     3/8/2024       Technology        Mouse   Mumbai    900     180
# 5    3/19/2024        Furniture        Table    Delhi   8500    1500
# 6     4/2/2024  Office Supplies     Notebook  Lucknow   1500     300
# 7    4/21/2024       Technology     Keyboard     Pune   2200     400
# 8    5/10/2024        Furniture         Sofa   Mumbai  25000    5000
# 9    5/25/2024  Office Supplies       Marker    Delhi    800     160
# 10    6/4/2024       Technology      Monitor  Lucknow  12000    2200
# 11   6/17/2024        Furniture    Bookshelf   Kanpur   7000    1200
# 12    7/6/2024  Office Supplies      Stapler     Pune    950     180
# 13   7/22/2024       Technology   Headphones    Delhi   3500     600
# 14   8/11/2024        Furniture          Bed   Mumbai  30000    6500
# 15   8/28/2024  Office Supplies  File Folder  Lucknow   1100     220
# 16    9/9/2024       Technology      Printer   Kanpur  15000    2500
# 17   9/24/2024        Furniture      Cabinet     Pune   9500    1700
# 18   10/5/2024  Office Supplies   Calculator    Delhi   1800     350
# 19  10/19/2024       Technology       Tablet   Mumbai  28000    4200
# 20   11/7/2024        Furniture         Desk  Lucknow   6500    1100
# 21  11/23/2024  Office Supplies     Envelope   Kanpur    500      90
# 22   12/3/2024       Technology       Webcam     Pune   2600     450
# 23  12/18/2024        Furniture        Stool    Delhi   2200     350
#
#     Quantity  Discount
# 0          2      0.00
# 1          1      0.05
# 2          3      0.10
# 3         10      0.00
# 4          5      0.00
# 5          2      0.08
# 6          6      0.00
# 7          4      0.03
# 8          1      0.12
# 9          8      0.00
# 10         2      0.06
# 11         1      0.05
# 12         4      0.00
# 13         3      0.02
# 14         1      0.10
# 15         7      0.00
# 16         1      0.07
# 17         2      0.04
# 18         2      0.00
# 19         1      0.05
# 20         2      0.06
# 21        12      0.00
# 22         3      0.01
# 23         5      0.00
# Product-wise Sales
# Product Name
# Bed            30000
# Bookshelf       7000
# Cabinet         9500
# Calculator      1800
# Chair           4500
# Desk            6500
# Envelope         500
# File Folder     1100
# Headphones      3500
# Keyboard        2200
# Laptop         55000
# Marker           800
# Monitor        12000
# Mouse            900
# Notebook        1500
# Paper           1200
# Pen              600
# Printer        15000
# Sofa           25000
# Stapler          950
# Stool           2200
# Table           8500
# Tablet         28000
# Webcam          2600
# Name: Sales, dtype: int64
# Category-wise Revenue
# Category
# Furniture           93200
# Office Supplies      8450
# Technology         119200
# Name: Revenue, dtype: int64
# City-wise Revenue
# City
# Delhi      71800
# Kanpur     23100
# Lucknow    25600
# Mumbai     85100
# Pune       15250
# Name: Revenue, dtype: int64
